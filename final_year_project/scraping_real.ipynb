# %%
from bs4 import BeautifulSoup
import requests
import time
import os
import urllib.request, json

from __future__ import absolute_import
from __future__ import division, print_function, unicode_literals

from sumy.parsers.html import HtmlParser
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer as Summarizer
from sumy.nlp.stemmers import Stemmer
from sumy.utils import get_stop_words

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
LANGUAGE = "english"
SENTENCES_COUNT = 10
stop_words = set(stopwords.words('english'))
stop_words.update(['.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}'])

# %%
def consize(url , filename):
    parser = HtmlParser.from_url(url, Tokenizer(LANGUAGE))
    stemmer = Stemmer(LANGUAGE)

    summarizer = Summarizer(stemmer)
    summarizer.stop_words = get_stop_words(LANGUAGE)
    
    counter = 1
    corpus = []
    corpus_new = []
    
    fopen = open(filename, 'w')
    fopen.write("Source :" + str(url) + "\n" + "Content :")
    for sentence in summarizer(parser.document, SENTENCES_COUNT):
        print(counter , ") ",  sentence)
        corpus.append(str(sentence).split(" "))
        corpus_new.append(str(sentence))
        
        word_tokens = word_tokenize(str(sentence))
        filtered_sentence = [w for w in word_tokens if not w in stop_words]
        filtered_sentence1 = ""
 
        for w in word_tokens:
            if w not in stop_words:
                filtered_sentence1 += str(w) + " "
 
        print(counter , ") ",  filtered_sentence1)
        print("-------")
        fopen.write(str(sentence) + "/*~*/")
        
        counter += 1
    fopen.close()

# %%
news_source = ["https://newsapi.org/v2/top-headlines?country=au&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?country=in&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=bbc-news&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=al-jazeera-english&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=cnbc&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=cnn&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=bloomberg&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=google-news&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=reddit-r-all&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=wired&apiKey=4d18fcdb680b4d8baac9709e2b2ec307", 
               "https://newsapi.org/v2/top-headlines?sources=the-guardian-uk&apiKey=4d18fcdb680b4d8baac9709e2b2ec307"
               "https://newsapi.org/v2/top-headlines?country=us&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=aftenposten&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=crypto-coins-news&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=financial-times&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=gruenderszene&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=ynet&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=the-huffington-post&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=the-telegraph&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=the-sport-bible&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=the-times-of-india&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=usa-today&apiKey=4d18fcdb680b4d8baac9709e2b2ec307",
               "https://newsapi.org/v2/top-headlines?sources=the-wall-street-journal&apiKey=4d18fcdb680b4d8baac9709e2b2ec307"]

news_source_name = ["bbc", 
                    "al-jazeer-english",
                    "cnbc", 
                    "cnn",
                    "bloomberg",
                    "google-news",
                    "reddit-r-all",
                    "wired", 
                    "the-guardian-uk"]

# %%
while 1:
    for neww in range(len(news_source)):
        with urllib.request.urlopen(news_source[neww]) as url:
            dirc=os.getcwd()
            data = json.loads(url.read().decode())
            #print(data)
            ts = int(time.time())
            total=data["totalResults"]
            for i in range(0,total):
                x=data["articles"][i]["url"]
                x__ = x.replace("/", "__")
                
                try:
                    #filename__=str(dirc)+'/Data/Real_consize/' + str(news_source_name[neww]) + '_' + str(i)+'_'+str(ts)+ '.txt'
                    filename__=str(dirc)+'/Data/Real_consize/' + str(x__) + '.txt'
                    consize(x, filename__)
                except: 
                    pass  
        time.sleep(60*2)
# Out:
# 1 )  A Western Australian family was relocating to Perth when a young mother and her 10-year-old son were killed and her three other children injured in a "catastrophic" truck crash in the state's wheatbelt region.
# 1 )  A Western Australian family relocating Perth young mother 10-year-old son killed three children injured `` catastrophic '' truck crash state 's wheatbelt region
# -------
# 2 )  Amy Slater, 26, and her son Leroy were unable to be revived after a semi-trailer crashed into their parked Holden Commodore on the Brookton-Corrigin Road near Corrigin about midnight
# 2 )  Amy Slater 26 son Leroy unable revived semi-trailer crashed parked Holden Commodore Brookton-Corrigin Road near Corrigin midnight
# -------
# 3 )  The car, which had been towing a trailer, had run out of petrol and the children's 27-year-old father had left to walk to Corrigin to get fuel.
# 3 )  The car towing trailer run petrol children 's 27-year-old father left walk Corrigin get fuel
# -------
# ...
